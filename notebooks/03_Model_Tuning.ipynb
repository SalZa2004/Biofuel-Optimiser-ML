# %% [markdown]
# # Model Optimisation and Tuning

# %%
import os
import pandas as pd
BASE_DIR = os.getcwd
BASE_DIR = os.path.dirname(os.getcwd())  # go up one directory


DB_PATH = os.path.join(BASE_DIR, "data", "database", "latest_fuel_database.db")
CANDIDATE_CSV = os.path.join(BASE_DIR, "data", "raw", "candidates_3.csv")

# %% [markdown]
# # Baseline Model Testing

# %%
baseline_results = pd.read_csv(os.path.join(BASE_DIR,"baseline_model_results.csv"))
print(baseline_results.sort_values('RMSE_test'))
# Out:
#              Unnamed: 0  MAE_train  MAE_test  RMSE_train  RMSE_test
# 4            ExtraTrees   0.244478  5.441341    1.290999   9.708448
# 1               XGBoost   0.997744  5.964328    1.701477   9.804764
# 0          RandomForest   2.370554  6.132934    3.856308  10.075577
# 3      GradientBoosting   5.084558  6.861618    6.662632  10.228670
# 5  HistGradientBoosting   1.997092  6.303653    3.734419  10.358266
# 2              LightGBM   2.021412  6.486806    3.999778  10.770176

# %% [markdown]
# # Feature Selection
